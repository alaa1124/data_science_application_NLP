# %% [markdown]
# <a href="https://colab.research.google.com/github/alaa1124/Data-Analysis-with-Python-and-SAS-viya-and-powerbi/blob/main/Text_Data_Partition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
import re
import nltk
import csv

from nltk.corpus import gutenberg, stopwords
import random
import pandas as pd

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
en_stops = set(stopwords.words('english'))
from nltk.tokenize import regexp_tokenize

# %%
import nltk
nltk.download('gutenberg')

from nltk.corpus import gutenberg
file_ids = gutenberg.fileids()
print(file_ids)
# Out:
# ['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt', 'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt', 'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt', 'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt', 'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt', 'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.

# %%
nltk.corpus.gutenberg.fileids()    
from nltk.corpus import gutenberg

# %%
listBooks=nltk.corpus.gutenberg.fileids()
listBooks
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
book=nltk.corpus.gutenberg.raw(listBooks[1])

# %%
toknize_book=regexp_tokenize(book,r'(\w{2,})[\s]')
len(toknize_book)
# Out:
# 67885

# %%
re.findall(r'([\w]{2,})[\s|\.]', book)
# Out:
# ['Persuasion',
#  'by',
#  'Jane',
#  'Austen',
#  'Chapter',
#  'Sir',
#  'Walter',
#  'of',
#  'Kellynch',
#  'in',
#  'was',
#  'man',
#  'for',
#  'his',
#  'own',
#  'never',
#  'took',
#  'up',
#  'any',
#  'book',
#  'but',
#  'the',
#  'there',
#  'he',
#  'found',
#  'occupation',
#  'for',
#  'an',
#  'idle',
#  'and',
#  'consolation',
#  'in',
#  'distressed',
#  'there',
#  'his',
#  'faculties',
#  'were',
#  'roused',
#  'into',
#  'admiration',
#  'and',
#  'by',
#  'contemplating',
#  'the',
#  'limited',
#  'remnant',
#  'of',
#  'the',
#  'earliest',
#  'there',
#  'any',
#  'unwelcome',
#  'arising',
#  'from',
#  'domestic',
#  'affairs',
#  'changed',
#  'naturally',
#  'into',
#  'pity',
#  'and',
#  'contempt',
#  'as',
#  'he',
#  'turned',
#  'over',
#  'the',
#  'almost',
#  'endless',
#  'creations',
#  'of',
#  'the',
#  'last',
#  'and',
#  'if',
#  'every',
#  'other',
#  'leaf',
#  'were',
#  'he',
#  'could',
#  'read',
#  'his',
#  'own',
# ...

# %%
def read_book(name):
    book=nltk.corpus.gutenberg.raw(name) 
    toknize_book=regexp_tokenize(book,r'(\w{2,})[\s]')
    list_of_part=[]
    for i in range(200):
        start=random.randint(0,len(toknize_book)-100)
        list_of_part.append(' '.join( toknize_book[start:start+100]))
    df=pd.DataFrame({"partitions":list_of_part,"label":re.sub(r".txt","",name)})
    return df

# %%
read_book(listBooks[3])
# Out:
#                                             partitions      label
# 0    is the altar of the burnt offering for And Dav...  bible-kjv
# 1    into seven and bring the description hither to...  bible-kjv
# 2    50 The lord of that servant shall come in day ...  bible-kjv
# 3    right and on their 23 And the Egyptians and we...  bible-kjv
# 4    he said to Gird up thy and take my staff in th...  bible-kjv
# ..                                                 ...        ...
# 195  of the and find it then will give you thirty s...  bible-kjv
# 196  of Tyre sent messengers to and cedar and and a...  bible-kjv
# 197  his 22 And she bare him and he called his name...  bible-kjv
# 198  law and to the if they speak not according to ...  bible-kjv
# 199  servant to wash the feet of the servants of my...  bible-kjv
#
# [200 rows x 2 columns]

# %%
data=pd.DataFrame()
df1=pd.DataFrame()
for name in listBooks:
    df1=read_book(name)
    data=data.append(df1,ignore_index=True)
# Out:
# <ipython-input-14-0eb7152ee5fd>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append(df1,ignore_index=True)
# <ipython-input-14-0eb7152ee5fd>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append(df1,ignore_index=True)
# <ipython-input-14-0eb7152ee5fd>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append(df1,ignore_index=True)
# <ipython-input-14-0eb7152ee5fd>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   data=data.append(df1,ignore_index=True)
# ...

# %%
data.tail(200)
# Out:
#                                              partitions           label
# 3400  mare shames silliness out of 14 The wild gande...  whitman-leaves
# 3401  to by it Yet in beginning incalculable masses ...  whitman-leaves
# 3402  of the foul Behold this behold it Perhaps ever...  whitman-leaves
# 3403  to sing the songs of the glory of not sooner t...  whitman-leaves
# 3404  is recovering and happy having week ago borne ...  whitman-leaves
# ...                                                 ...             ...
# 3595  in any what is Round and round we all of and e...  whitman-leaves
# 3596  of growing Of men that live among cattle or ta...  whitman-leaves
# 3597  the rivers The separate countless free like Th...  whitman-leaves
# 3598  or her set out in search of this My final meri...  whitman-leaves
# 3599  and of the merry word and laughing Joy of the ...  whitman-leaves
#
# [200 rows x 2 columns]
